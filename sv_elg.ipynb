# %%
'''
    systematic weights for ELG SV


'''
# %matplotlib inline
import matplotlib.pyplot as plt
import fitsio as ft
import numpy  as np
import healpy as hp

# %%
ngal = hp.read_map('/home/mehdi/data/formehdi/dr8_elgsv_ngal.hp.256.fits')
frac = hp.read_map('/home/mehdi/data/formehdi/dr8_elgsv_frac.hp.256.fits')
mask = hp.read_map('/home/mehdi/data/formehdi/dr8_mask_eBOSS.hp256.fits')
# Out:
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/pixelfunc.py:345: RuntimeWarning: invalid value encountered in less_equal
#   return np.absolute(m - badval) <= atol + rtol * np.absolute(badval)

# %%
ngal = ngal/frac
# Out:
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
ngalm = hp.ma(ngal)
ngalm.mask = np.logical_not(mask)

# %%
ngalm.filled()
# Out:
# array([-1.6375e+30, -1.6375e+30, -1.6375e+30, ..., -1.6375e+30,
#        -1.6375e+30, -1.6375e+30])

# %%
hp.mollview(ngalm.filled())
# Out:
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/pixelfunc.py:345: RuntimeWarning: invalid value encountered in less_equal
#   return np.absolute(m - badval) <= atol + rtol * np.absolute(badval)
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/projaxes.py:1196: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if matplotlib.cbook.iterable(value):
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/projaxes.py:1155: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if matplotlib.cbook.iterable(value):
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/projaxes.py:1176: RuntimeWarning: invalid value encountered in less
#   result.data[result.data < 0] = 0.0
# ...

# %%
maskn = hp.read_map('/home/mehdi/data/formehdi/0.2/dr8_elgsv_mask_ngc.hp.256.fits')
# Out:
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT

# %%
hp.mollview(maskn)
# Out:
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/projaxes.py:1196: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if matplotlib.cbook.iterable(value):
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/projaxes.py:1155: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if matplotlib.cbook.iterable(value):

# %%
data = ft.read('/home/mehdi/data/formehdi/pixweight_ar-dr8-0.32.0-elgsv-eBOSS.fits')
data.dtype.names, data.size
# Out:
# (('HPXPIXEL',
#   'FRACAREA',
#   'PSFDEPTH_G',
#   'PSFDEPTH_R',
#   'PSFDEPTH_Z',
#   'GALDEPTH_G',
#   'GALDEPTH_R',
#   'GALDEPTH_Z',
#   'PSFDEPTH_W1',
#   'PSFDEPTH_W2',
#   'PSFSIZE_G',
#   'PSFSIZE_R',
#   'PSFSIZE_Z',
#   'EBV',
#   'STARDENS',
#   'RA',
#   'DEC',
#   'GALL',
#   'GALB',
#   'ISNORTH',
#   'ISSOUTH',
#   'ISDES',
#   'ELGFRACAREA',
#   'ELGFRACPSF',
#   'ELGFRACREX',
#   'ELGFRACEXP',
#   'ELGFRACDEV',
#   'ELGFRACCOMP',
#   'SV',
#   'MAIN',
#   'MAIN_FAINT',
#   'BLUE',
#   'RED'),
#  91142)

# %%
np.unique(data['HPXPIXEL']).size
# Out:
# 91142

# %%
mask = np.zeros(12*256*256, '?')

# %%
mask[data['HPXPIXEL'].astype('int')] = True

# %%
hp.mollview(mask, nest=True)
# Out:
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/projaxes.py:1196: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if matplotlib.cbook.iterable(value):
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/projaxes.py:1155: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if matplotlib.cbook.iterable(value):

# %%
maskr = hp.reorder(mask, n2r=True)

# %%
hp.mollview(maskr)
# Out:
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/projaxes.py:1196: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if matplotlib.cbook.iterable(value):
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/projaxes.py:1155: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if matplotlib.cbook.iterable(value):

# %%
hp.write_map('/home/mehdi/data/formehdi/dr8_mask_eBOSS.hp256.fits', maskr, fits_IDL=False,
            dtype=np.float64)

# %%
hp.reorder?

# %%
np.isnan(data['SV']).sum()
# Out:
# 0

# %%
plt.scatter(data['RA'], data['DEC'], 1.,
           c=data['SV'], cmap=plt.cm.jet)
plt.colorbar()

# %%
(data['ISNORTH'] | data['ISSOUTH'] | data['ISDES']).sum()
# Out:
# 90032

# %%
(np.isnan(data['SV'])).sum()
# Out:
# 0

# %%
data['SV'].min()
# Out:
# 0.0

# %%
import pandas as pd

# %%
import fitsio as ft

# %%
import healpy as hp

# %%
g = hp.read_map('/home/mehdi/data/formehdi/dr8_elgsv_ngal.hp.256.fits')
# Out:
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/healpy/pixelfunc.py:345: RuntimeWarning: invalid value encountered in less_equal
#   return np.absolute(m - badval) <= atol + rtol * np.absolute(badval)

# %%
gn = hp.reorder(g, r2n=True)

# %%
ind = data['HPXPIXEL'].astype('int')

# %%
np.array_equal(gn[ind], data['SV']*data['FRACAREA'] * hp.nside2pixarea(256, degrees=True))
# Out:
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in multiply
#   """Entry point for launching an IPython kernel.
# False

# %%
(gn[ind] - data['SV']*data['FRACAREA'] * hp.nside2pixarea(256, degrees=True)).min()
# Out:
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in multiply
#   """Entry point for launching an IPython kernel.
# nan

# %%
gn.max()
# Out:
# nan

# %%
plt.scatter(gn[ind], data['SV']*data['FRACAREA'] * hp.nside2pixarea(256, degrees=True))
# Out:
# /home/mehdi/miniconda3/envs/py3p6/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in multiply
#   """Entry point for launching an IPython kernel.

# %%
data2 = pd.read_hdf('/home/mehdi/data/formehdi/dr8_elgsv.h5'a
                   )
